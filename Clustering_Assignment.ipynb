# %% [markdown]
# ### Q1: What is unsupervised learning in the context of machine learning

# %% [markdown]
# Unsupervised learning is a type of machine learning where the algorithm learns patterns from unlabeled data—meaning there are no predefined outputs or target variables.

# %% [markdown]
# ### Q2: How does K-Means clustering algorithm work

# %% [markdown]
# K-Means partitions the data into K clusters, where each data point belongs to the cluster with the nearest centroid (center of cluster)
#
# Algorithm Steps:
# Choose K: Decide how many clusters (K) you want.
#
# Initialize: Randomly select K points as the initial centroids.
#
# Assign Clusters:
#
# For each data point, compute the distance to each centroid.
#
# Assign the point to the nearest centroid.
#
# Update Centroids:
#
# Recalculate the centroid of each cluster as the mean of the points assigned to it.
#
# Repeat:
#
# Repeat steps 3 & 4 until centroids no longer move significantly (convergence) or a max number of iterations is reached.

# %% [markdown]
# ### Q3: Explain the concept of a dendrogram in hierarchical clustering

# %% [markdown]
# A dendrogram is a tree-like diagram that visually represents the process of hierarchical clustering. It shows how data points (or clusters) are merged step-by-step based on their similarity (or distance).

# %% [markdown]
# ### Q4: What is the main difference between K-Means and Hierarchical Clustering

# %% [markdown]
# K-Means: Efficient, requires predefined number of clusters, works best for spherical, similarly sized clusters.
#
# Hierarchical: Builds nested clusters, good for understanding data structure, doesn't need k in advance.

# %% [markdown]
# ### Q5: What are the advantages of DBSCAN over K-Means

# %% [markdown]
# DBSCAN is great for density-based clustering, noisy datasets, and complex shapes.
#
# K-Means is fast and efficient but requires more assumptions about the data.

# %% [markdown]
# ### Q6: When would you use Silhouette Score in clustering

# %% [markdown]
# The Silhouette Score is used in clustering to measure how well data points fit within their assigned clusters — and here's when and why you'd use it:
#
# To Choose the Optimal Number of Clusters (k):
#
# If you're unsure how many clusters to use (especially in K-Means), you can compute the silhouette score for different values of k and pick the one with the highest score.
#
# To Evaluate Clustering Performance:
#
# After applying a clustering algorithm (like K-Means, DBSCAN, etc.), silhouette score helps you understand how cohesive and separated the clusters are.
#
# To Compare Clustering Algorithms:
#
# Run different clustering methods (e.g., K-Means vs. Agglomerative) and compare their silhouette scores to pick the best one.

# %% [markdown]
# ### Q7: What are the limitations of Hierarchical Clustering

# %% [markdown]
# Not Scalable to Large Datasets
# Time complexity is typically O(n²) or worse.
#
# Doesn’t perform well with large numbers of data points — becomes slow and memory-intensive.
#
# Irreversible Merges/Splits
# Once a merge or split is done, it can’t be undone.
#
# This makes it sensitive to early decisions that might be incorrect.
#
# Sensitive to Noise and Outliers
# Even a few outliers can significantly distort the clustering structure, especially in single-linkage clustering.
#
# Choice of Linkage Method Affects Results
# Different linkage methods (single, complete, average, ward) can produce very different dendrograms and clusters.
#
# No Clear Objective Function
# Unlike K-Means which minimizes intra-cluster variance, hierarchical clustering lacks a clear optimization goal, making it harder to evaluate quality.
#
# Requires Distance Matrix
# It needs a full distance matrix, which takes up O(n²) space, again limiting scalability.

# %% [markdown]
# ### Q8: Why is feature scaling important in clustering algorithms like K-Means

# %% [markdown]
# 1. K-Means is Distance-Based
# 2. Unscaled Features Can Skew Centroids
# 3. Ensures Equal Contribution

# %% [markdown]
# ### Q9: How does DBSCAN identify noise points

# %% [markdown]
# DBSCAN groups together points that are densely packed, and marks as noise those that don’t fit well into any cluster.

# %% [markdown]
# ### Q10: Define inertia in the context of K-Means

# %% [markdown]
# Inertia is a measure of how well the data points are clustered around the centroids in K-Means. It’s one of the key metrics used to evaluate how good your clustering is.

# %% [markdown]
# ### Q11: What is the elbow method in K-Means clustering

# %% [markdown]
# The Elbow Method is a technique used to determine the optimal number of clusters (k) in K-Means clustering.

# %% [markdown]
# ### Q12: Describe the concept of 'density' in DBSCAN

# %% [markdown]
# In DBSCAN (Density-Based Spatial Clustering of Applications with Noise), the concept of density plays a central role in identifying clusters. Instead of using distance alone (like K-Means), DBSCAN groups points based on how densely packed they are.

# %% [markdown]
# ### Q13: Can hierarchical clustering be used on categorical data

# %% [markdown]
# Yes, hierarchical clustering can be used on categorical data, but with a few important considerations and adaptations.

# %% [markdown]
# ### Q14: What does a negative Silhouette Score indicate

# %% [markdown]
# A negative silhouette score is a clear sign that a data point has been incorrectly clustered

# %% [markdown]
# ### Q15: Explain the term 'linkage criteria' in hierarchical clustering

# %% [markdown]
# In hierarchical clustering, the linkage criteria determine how the distance between clusters is calculated during the merging process.

# %% [markdown]
# ### Q16: Why might K-Means clustering perform poorly on data with varying cluster sizes or densities

# %% [markdown]
# K-Means clustering assumes that:
#
# Clusters are spherical (equally sized),
#
# Each cluster has a similar number of points (balanced),
#
# All clusters have similar density.

# %% [markdown]
# ### Q17: What are the core parameters in DBSCAN, and how do they influence clustering

# %% [markdown]
# DBSCAN (Density-Based Spatial Clustering of Applications with Noise) is a powerful clustering algorithm, especially for arbitrary-shaped clusters and datasets with noise. It relies on density rather than distance to group data points.

# %% [markdown]
# ### Q18: How does K-Means++ improve upon standard K-Means initialization

# %% [markdown]
# ### Q19: What is agglomerative clustering

# %% [markdown]
# ### Q20: What makes Silhouette Score a better metric than just inertia for model evaluation?

# %% [markdown]
# ### Practical Questions

# %% [markdown]
# #### Generate synthetic data with 4 centers using make_blobs and apply K-Means clustering. Visualize using a scatter plot

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# Generate a small synthetic dataset with 4 centers
X, y_true = make_blobs(n_samples=20, centers=4, cluster_std=0.6, random_state=42)

# Apply K-Means clustering
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
y_kmeans = kmeans.fit_predict(X)

# Visualize using scatter plot
plt.figure(figsize=(6, 4))
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, cmap='viridis', s=60)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
            c='red', s=120, marker='X', label='Centroids')
plt.title("K-Means on Small Dataset (4 Centers)")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ####  Load the Iris dataset and use Agglomerative Clustering to group the data into 3 clusters. Display the first 10 predicted labels

# %%
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering
import pandas as pd

# Load the Iris dataset
iris = load_iris()
X = iris.data[:30]  # Use only the first 30 samples to keep it small

# Apply Agglomerative Clustering
agg = AgglomerativeClustering(n_clusters=3)
labels = agg.fit_predict(X)

# Display the first 10 predicted labels
print("First 10 predicted labels:", labels[:10])
# Out:
# First 10 predicted labels: [2 0 0 0 2 1 0 2 0 0]

# %% [markdown]
# #### Generate synthetic data using make_moons and apply DBSCAN. Highlight outliers in the plot

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN

# Generate small synthetic data
X, _ = make_moons(n_samples=100, noise=0.1, random_state=42)

# Apply DBSCAN
db = DBSCAN(eps=0.3, min_samples=5)
labels = db.fit_predict(X)

# Plot clusters
plt.figure(figsize=(6, 4))
# Outliers are labeled as -1
plt.scatter(X[labels != -1][:, 0], X[labels != -1][:, 1], c=labels[labels != -1], cmap='viridis', label='Clusters')
plt.scatter(X[labels == -1][:, 0], X[labels == -1][:, 1], c='red', marker='x', label='Outliers')
plt.title("DBSCAN Clustering with make_moons")
plt.legend()
plt.show()

# %% [markdown]
# ####  Load the Wine dataset and apply K-Means clustering after standardizing the features. Print the size of each cluster

# %%
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import numpy as np

# Load dataset
data = load_wine()
X = data.data

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply K-Means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
labels = kmeans.fit_predict(X_scaled)

# Print size of each cluster
unique, counts = np.unique(labels, return_counts=True)
for cluster, size in zip(unique, counts):
    print(f"Cluster {cluster}: {size} samples")
# Out:
# Cluster 0: 65 samples
# Cluster 1: 51 samples
# Cluster 2: 62 samples
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# #### Use make_circles to generate synthetic data and cluster it using DBSCAN. Plot the result

# %%
from sklearn.datasets import make_circles
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# Generate synthetic circular data
X, _ = make_circles(n_samples=300, factor=0.5, noise=0.05, random_state=42)

# Apply DBSCAN
dbscan = DBSCAN(eps=0.2, min_samples=5)
labels = dbscan.fit_predict(X)

# Plot the clusters
plt.figure(figsize=(6, 4))
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', edgecolor='k')
plt.title("DBSCAN Clustering on make_circles Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %% [markdown]
# ####  Load the Breast Cancer dataset, apply MinMaxScaler, and use K-Means with 2 clusters. Output the cluster centroids

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import numpy as np

# Load dataset
data = load_breast_cancer()
X = data.data

# Apply MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Apply KMeans with 2 clusters
kmeans = KMeans(n_clusters=2, random_state=42, n_init='auto')
kmeans.fit(X_scaled)

# Output cluster centroids
print("Cluster Centroids:\n", kmeans.cluster_centers_)
# Out:
# Cluster Centroids:
#  [[0.50483563 0.39560329 0.50578661 0.36376576 0.46988732 0.42226302
#   0.41838662 0.46928035 0.45899738 0.29945886 0.19093085 0.19112073
#   0.17903433 0.13086432 0.18017962 0.25890126 0.12542475 0.30942779
#   0.190072   0.13266975 0.48047448 0.45107371 0.4655302  0.31460597
#   0.49868817 0.36391461 0.39027292 0.65827197 0.33752296 0.26041387]
#  [0.25535358 0.28833455 0.24696416 0.14388369 0.35743076 0.18019471
#   0.10344776 0.1306603  0.34011829 0.25591606 0.06427485 0.18843043
#   0.05975663 0.02870108 0.18158628 0.13242941 0.05821528 0.18069336
#   0.17221057 0.08403996 0.2052406  0.32069002 0.19242138 0.09943446
#   0.3571115  0.14873935 0.13142287 0.26231363 0.22639412 0.15437354]]
# ...

# %% [markdown]
# #### Generate synthetic data using make_blobs with varying cluster standard deviations and cluster with DBSCAN

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# Generate synthetic data with varying standard deviations
X, _ = make_blobs(n_samples=200, centers=3, cluster_std=[0.5, 1.5, 0.8], random_state=42)

# Apply DBSCAN
db = DBSCAN(eps=0.6, min_samples=5)
labels = db.fit_predict(X)

# Plot results
plt.figure(figsize=(6, 4))
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', edgecolor='k')
plt.title("DBSCAN on make_blobs with Varying Cluster Std")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)
plt.show()

# %% [markdown]
# ####  Load the Digits dataset, reduce it to 2D using PCA, and visualize clusters from K-Means

# %%
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Load Digits dataset
digits = load_digits()
X = digits.data

# Reduce to 2D with PCA
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X)

# Apply K-Means
kmeans = KMeans(n_clusters=10, random_state=42)
labels = kmeans.fit_predict(X_pca)

# Plot results
plt.figure(figsize=(6, 4))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='tab10', s=30, edgecolor='k')
plt.title("K-Means Clustering on Digits (PCA-Reduced)")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Create synthetic data using make_blobs and evaluate silhouette scores for k = 2 to 5. Display as a bar chart

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# Generate synthetic data
X, _ = make_blobs(n_samples=100, centers=4, cluster_std=0.60, random_state=42)

# Range of k values
k_values = range(2, 6)
scores = []

# Compute silhouette scores for each k
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X)
    score = silhouette_score(X, labels)
    scores.append(score)

# Plot silhouette scores
plt.figure(figsize=(6, 4))
plt.bar(k_values, scores, color='skyblue')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Scores for k = 2 to 5')
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %% [markdown]
# ####  Load the Iris dataset and use hierarchical clustering to group data. Plot a dendrogram with average linkage

# %%
from sklearn.datasets import load_iris
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = load_iris()
X = iris.data

# Perform hierarchical clustering with average linkage
linked = linkage(X, method='average')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(linked, truncate_mode='lastp', p=30, leaf_rotation=90., leaf_font_size=10.)
plt.title('Hierarchical Clustering Dendrogram (Average Linkage)')
plt.xlabel('Sample Index or Cluster Size')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# #### Generate synthetic data with overlapping clusters using make_blobs, then apply K-Means and visualize with decision boundaries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from matplotlib.colors import ListedColormap

# Generate synthetic overlapping data
X, _ = make_blobs(n_samples=150, centers=3, cluster_std=1.5, random_state=42)

# Apply K-Means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# Plot decision boundaries
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.05),
                     np.arange(y_min, y_max, 0.05))
Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.figure(figsize=(8, 5))
plt.contourf(xx, yy, Z, alpha=0.3, cmap=ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF']))
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=40, edgecolor='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], 
            c='black', s=200, marker='X', label='Centroids')
plt.title("K-Means Clustering with Decision Boundaries")
plt.legend()
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# #### Load the Digits dataset and apply DBSCAN after reducing dimensions with t-SNE. Visualize the results

# %%
from sklearn.datasets import load_digits
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# Load Digits dataset
digits = load_digits()
X = digits.data

# Standardize the data
X_scaled = StandardScaler().fit_transform(X)

# Reduce dimensions to 2D using t-SNE
X_tsne = TSNE(n_components=2, random_state=42, perplexity=30).fit_transform(X_scaled)

# Apply DBSCAN
dbscan = DBSCAN(eps=2, min_samples=5)
labels = dbscan.fit_predict(X_tsne)

# Plot the results
plt.figure(figsize=(8, 5))
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=labels, cmap='tab10', s=15)
plt.title("DBSCAN Clustering on Digits (2D via t-SNE)")
plt.colorbar(scatter, label="Cluster Label (-1 means noise)")
plt.show()

# %% [markdown]
# #### Generate synthetic data using make_blobs and apply Agglomerative Clustering with complete linkage. Plot the result

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# Generate small synthetic data with 3 centers
X, _ = make_blobs(n_samples=60, centers=3, cluster_std=1.0, random_state=42)

# Apply Agglomerative Clustering with complete linkage
agg = AgglomerativeClustering(n_clusters=3, linkage='complete')
labels = agg.fit_predict(X)

# Plot the clusters
plt.figure(figsize=(6, 4))
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=40)
plt.title("Agglomerative Clustering (Complete Linkage)")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Load the Breast Cancer dataset and compare inertia values for K = 2 to 6 using K-Means. Show results in a line plot

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Load dataset and scale
data = load_breast_cancer()
X = StandardScaler().fit_transform(data.data)

# Calculate inertia for K = 2 to 6
inertia = []
k_values = range(2, 7)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

# Plot inertia values
plt.figure(figsize=(6, 4))
plt.plot(k_values, inertia, marker='o')
plt.title("K-Means Inertia for K=2 to 6 (Breast Cancer Dataset)")
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia")
plt.grid(True)
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# ...

# %% [markdown]
# #### Generate synthetic concentric circles using make_circles and cluster using Agglomerative Clustering with single linkage

# %%
from sklearn.datasets import make_circles
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# Generate concentric circles
X, _ = make_circles(n_samples=200, factor=0.5, noise=0.05, random_state=42)

# Apply Agglomerative Clustering with single linkage
agglo = AgglomerativeClustering(n_clusters=2, linkage='single')
labels = agglo.fit_predict(X)

# Plot the result
plt.figure(figsize=(6, 4))
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=30)
plt.title("Agglomerative Clustering with Single Linkage on Concentric Circles")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Use the Wine dataset, apply DBSCAN after scaling the data, and count the number of clusters (excluding noise

# %%
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import numpy as np

# Load the Wine dataset
data = load_wine()
X = data.data

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply DBSCAN
dbscan = DBSCAN(eps=1.5, min_samples=5)
labels = dbscan.fit_predict(X_scaled)

# Count the number of clusters (excluding noise label -1)
n_clusters = len(set(labels)) - (1 if -1 in labels else 0)

# Output the result
print("Number of clusters (excluding noise):", n_clusters)
print("Number of noise points:", np.sum(labels == -1))
# Out:
# Number of clusters (excluding noise): 0
# Number of noise points: 178

# %% [markdown]
# #### Generate synthetic data with make_blobs and apply KMeans. Then plot the cluster centers on top of the data points

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# Generate synthetic data with 3 centers
X, _ = make_blobs(n_samples=100, centers=3, random_state=42)

# Apply KMeans
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# Plot data points with cluster centers
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50)
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='X', s=200, label='Centers')
plt.title("KMeans Clustering with Cluster Centers")
plt.legend()
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ####  Load the Iris dataset, cluster with DBSCAN, and print how many samples were identified as noise

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import numpy as np

# Load Iris dataset
iris = load_iris()
X = iris.data

# Standardize features
X_scaled = StandardScaler().fit_transform(X)

# Apply DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels = dbscan.fit_predict(X_scaled)

# Count noise points (label = -1)
n_noise = np.sum(labels == -1)
print("Number of noise points:", n_noise)
# Out:
# Number of noise points: 34

# %% [markdown]
# #### Generate synthetic non-linearly separable data using make_moons, apply K-Means, and visualize the clustering result

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import KMeans

# Generate synthetic non-linear data
X, _ = make_moons(n_samples=200, noise=0.1, random_state=42)

# Apply KMeans clustering
kmeans = KMeans(n_clusters=2, random_state=42)
labels = kmeans.fit_predict(X)

# Visualize the clustering result
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=30)
plt.title("K-Means on make_moons Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ####  Load the Digits dataset, apply PCA to reduce to 3 components, then use KMeans and visualize with a 3D scatter plot

# %%
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Required for 3D plotting

# Load the Digits dataset
digits = load_digits()
X = digits.data

# Reduce to 3 principal components
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X)

# Apply KMeans clustering
kmeans = KMeans(n_clusters=10, random_state=42)
labels = kmeans.fit_predict(X_pca)

# 3D Scatter plot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=labels, cmap='tab10', s=30)

ax.set_title("3D PCA of Digits Dataset with KMeans Clustering")
ax.set_xlabel("PCA 1")
ax.set_ylabel("PCA 2")
ax.set_zlabel("PCA 3")
plt.show()

# %% [markdown]
# ####  Generate synthetic blobs with 5 centers and apply KMeans. Then use silhouette_score to evaluate the clustering

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# Generate synthetic data with 5 clusters
X, _ = make_blobs(n_samples=100, centers=5, cluster_std=0.7, random_state=42)

# Apply KMeans
kmeans = KMeans(n_clusters=5, random_state=42)
labels = kmeans.fit_predict(X)

# Compute silhouette score
score = silhouette_score(X, labels)
print("Silhouette Score:", round(score, 3))

# Visualize the clusters
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='tab10', s=30)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], color='black', marker='x', s=100)
plt.title("KMeans Clustering with 5 Centers")
plt.show()
# Out:
# Silhouette Score: 0.776
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ####  Load the Breast Cancer dataset, reduce dimensionality using PCA, and apply Agglomerative Clustering. Visualize in 2D

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# Load and scale the data
data = load_breast_cancer()
X = StandardScaler().fit_transform(data.data)

# Reduce dimensions to 2D with PCA
X_pca = PCA(n_components=2, random_state=42).fit_transform(X)

# Apply Agglomerative Clustering
agglo = AgglomerativeClustering(n_clusters=2)
labels = agglo.fit_predict(X_pca)

# Visualize
plt.figure(figsize=(8, 5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='Set1', s=30)
plt.title("Agglomerative Clustering (PCA-reduced Breast Cancer Data)")
plt.xlabel("PC 1")
plt.ylabel("PC 2")
plt.grid(True)
plt.show()

# %% [markdown]
# ####  Generate noisy circular data using make_circles and visualize clustering results from KMeans and DBSCAN side-by-side

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
from sklearn.cluster import KMeans, DBSCAN

# Generate noisy circular data
X, _ = make_circles(n_samples=300, factor=0.5, noise=0.05, random_state=42)

# Apply KMeans
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans_labels = kmeans.fit_predict(X)

# Apply DBSCAN
dbscan = DBSCAN(eps=0.2, min_samples=5)
dbscan_labels = dbscan.fit_predict(X)

# Plotting side-by-side
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# KMeans plot
axs[0].scatter(X[:, 0], X[:, 1], c=kmeans_labels, cmap='viridis', s=30)
axs[0].set_title("KMeans Clustering")

# DBSCAN plot
axs[1].scatter(X[:, 0], X[:, 1], c=dbscan_labels, cmap='viridis', s=30)
axs[1].set_title("DBSCAN Clustering")

plt.suptitle("Clustering of Noisy Circular Data")
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %% [markdown]
# ####  Load the Iris dataset and plot the Silhouette Coefficient for each sample after KMeans clustering

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
import numpy as np

# Load Iris dataset
iris = load_iris()
X = iris.data

# Apply KMeans
kmeans = KMeans(n_clusters=3, random_state=42)
labels = kmeans.fit_predict(X)

# Compute silhouette scores for each sample
silhouette_vals = silhouette_samples(X, labels)

# Plot silhouette scores
plt.figure(figsize=(8, 5))
y_lower = 10
for i in np.unique(labels):
    ith_cluster_silhouette_vals = silhouette_vals[labels == i]
    ith_cluster_silhouette_vals.sort()
    
    size_cluster_i = ith_cluster_silhouette_vals.shape[0]
    y_upper = y_lower + size_cluster_i
    
    plt.fill_betweenx(np.arange(y_lower, y_upper),
                      0, ith_cluster_silhouette_vals,
                      alpha=0.7, label=f'Cluster {i}')
    
    y_lower = y_upper + 10  # space between clusters

# Global average silhouette score
avg_score = silhouette_score(X, labels)
plt.axvline(avg_score, color="red", linestyle="--", label="Average Score")

plt.title("Silhouette Coefficient for each sample (KMeans on Iris)")
plt.xlabel("Silhouette coefficient values")
plt.ylabel("Clustered samples")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ####  Generate synthetic data using make_blobs and apply Agglomerative Clustering with 'average' linkage. Visualize clusters

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering

# Generate synthetic data
X, _ = make_blobs(n_samples=100, centers=3, cluster_std=1.0, random_state=42)

# Apply Agglomerative Clustering with 'average' linkage
agglo = AgglomerativeClustering(n_clusters=3, linkage='average')
labels = agglo.fit_predict(X)

# Plot the clusters
plt.figure(figsize=(6, 5))
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50)
plt.title("Agglomerative Clustering with 'average' linkage")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ####   Load the Wine dataset, apply KMeans, and visualize the cluster assignments in a seaborn pairplot (first 4 features)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.cluster import KMeans

# Load Wine dataset
wine = load_wine()
X = pd.DataFrame(wine.data, columns=wine.feature_names)

# Use only the first 4 features
X_subset = X.iloc[:, :4]

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X_subset)

# Add cluster labels to the DataFrame
X_subset['Cluster'] = clusters

# Create pairplot
sns.pairplot(X_subset, hue='Cluster', palette='Set1', diag_kind='kde')
plt.suptitle("KMeans Clustering on Wine Dataset (First 4 Features)", y=1.02)
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ITProFound_Hyd_024\AppData\Local\Temp\ipykernel_4892\2078595236.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_subset['Cluster'] = clusters

# %% [markdown]
# ####  Generate noisy blobs using make_blobs and use DBSCAN to identify both clusters and noise points. Print the count

# %%
import numpy as np
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# Generate synthetic data with noise
X, _ = make_blobs(n_samples=100, centers=3, cluster_std=0.60, random_state=0)
noise = np.random.uniform(low=-10, high=10, size=(10, 2))  # Adding some noise points
X = np.vstack([X, noise])

# Apply DBSCAN
dbscan = DBSCAN(eps=0.8, min_samples=5)
labels = dbscan.fit_predict(X)

# Count clusters and noise
n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
n_noise = list(labels).count(-1)

print("Number of clusters (excluding noise):", n_clusters)
print("Number of noise points:", n_noise)

# Visualize
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='plasma', s=50)
plt.title("DBSCAN Clustering with Noise")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
# Out:
# Number of clusters (excluding noise): 2
# Number of noise points: 11

# %% [markdown]
# ####  Load the Digits dataset, reduce dimensions using t-SNE, then apply Agglomerative Clustering and plot the clusters

# %%
from sklearn.datasets import load_digits
from sklearn.manifold import TSNE
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# Load the Digits dataset
digits = load_digits()
X = digits.data
y = digits.target  # Not used for clustering, just for reference

# Reduce to 2D using t-SNE for visualization
tsne = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=300)
X_tsne = tsne.fit_transform(X)

# Apply Agglomerative Clustering
agg = AgglomerativeClustering(n_clusters=10)
labels = agg.fit_predict(X_tsne)

# Plot the result
plt.figure(figsize=(8, 6))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=labels, cmap='tab10', s=30)
plt.title("Agglomerative Clustering on t-SNE Reduced Digits Dataset")
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.colorbar(label='Cluster Label')
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
