# %% [markdown]
# ### Theoretical

# %% [markdown]
# #### What is Logistic Regression, and how does it differ from Linear Regression

# %% [markdown]
# Logistic Regression and Linear Regression are both statistical models used for predictive analysis, but they are used for different types of problems.
#
# Logistic Regression:
# Used for classification tasks (e.g., spam vs. not spam, pass vs. fail).
#
# Predicts probabilities of an outcome belonging to a particular class.
#
# Uses the sigmoid (logistic) function to map outputs between 0 and 1.
#
# The decision boundary is determined based on a probability threshold (e.g., 0.5).

# %% [markdown]
# #### What is the mathematical equation of Logistic Regression

# %% [markdown]
# The mathematical equation of Logistic Regression is based on the sigmoid function, which maps any real number to a value between 0 and 1. It is used for binary classification.
#
# Equation:
#
# P(y=1∣x)=σ(z)= 1/ 1+e −z

# %% [markdown]
# #### Why do we use the Sigmoid function in Logistic Regression

# %% [markdown]
# We use the sigmoid function in Logistic Regression because it transforms any real-valued input into a probability value between 0 and 1, making it ideal for binary classification. Here’s why it is essential:
#
# 1. Probability Interpretation
# 2. Non-Linearity for Decision Boundaries
# 3. Differentiability for Gradient Descent
# 4. Maps Any Real Number to (0,1) Range
# 5. Prevents Extreme Predictions

# %% [markdown]
# ####  What is the cost function of Logistic Regression

# %% [markdown]
# The cost function of Logistic Regression is the Log Loss (Logarithmic Loss), also known as the Binary Cross-Entropy Loss. It measures how well the model's predicted probabilities match the actual class labels.
#
# J(w)=− m1i=1∑m[y (i)log( y^(i))+(1−y (i))log(1− y^(i) )]

# %% [markdown]
# #### What is Regularization in Logistic Regression? Why is it needed

# %% [markdown]
# Regularization is a technique used to prevent overfitting by adding a penalty to the cost function. In Logistic Regression, regularization helps to keep the model simple and generalizable by discouraging excessively large weights.
#
# Why is Regularization Needed?
#
# Prevents Overfitting: Without regularization, the model might memorize noise and perform poorly on new data.
#
# Controls Model Complexity: Regularization keeps weights small, reducing model variance.
#
# Improves Generalization: A well-regularized model performs better on unseen data.

# %% [markdown]
# ####  Explain the difference between Lasso, Ridge, and Elastic Net regression

# %% [markdown]
# 1. Lasso Regression (L1 Regularization):-
#
# Uses absolute value of coefficients as the penalty.
#
# Can eliminate some features by setting coefficients to zero (good for feature selection).
#
# Helps in creating sparse models.
#
# 2. Ridge Regression (L2 Regularization):-
#
# Uses squared values of coefficients as the penalty.
#
# Reduces all weights but does not set them to zero.
#
# Works well when features are highly correlated.
#
# 3. Elastic Net Regression (L1 + L2):-
#
# Combines both L1 (Lasso) and L2 (Ridge) penalties.
#
# Helps when Lasso is too aggressive and Ridge is too weak.
#
# Useful when features are correlated but feature selection is still needed.

# %% [markdown]
# #### When should we use Elastic Net instead of Lasso or Ridge

# %% [markdown]
# Elastic Net combines the strengths of both Lasso (L1) and Ridge (L2) regularization, making it a better choice in certain situations.
#
# 1. When Features Are Highly Correlated
# 2. When You Need Feature Selection, But Lasso is Too Aggressive
# 3. When You Have More Features Than Observations (High-Dimensional Data)

# %% [markdown]
# #### What is the impact of the regularization parameter (λ) in Logistic Regression

# %% [markdown]
# The regularization parameter λ controls the balance between model complexity and generalization by adjusting the penalty on large coefficients.
#
# 1. Effect of λ on Model Complexity
# 2. Effect of λ on Decision Boundary
# 3. How to Choose the Right λ?

# %% [markdown]
# ####  What are the key assumptions of Logistic Regression

# %% [markdown]
# While Logistic Regression is a widely used classification algorithm, it comes with certain assumptions that must be met for optimal performance.
#
# 1. The Dependent Variable is Binary (or Multinomial)
# 2. Independence of Observations
# 3. No Multicollinearity Among Independent Variables
# 4. The Relationship Between Independent Variables and Log-Odds is Linear
# 5. Large Sample Size
# 6. No Extreme Outliers

# %% [markdown]
# #### What are some alternatives to Logistic Regression for classification tasks

# %% [markdown]
# While Logistic Regression is a popular and interpretable classification model, it may not always be the best choice, especially for complex or high-dimensional data. Below are some alternatives:
#
# 1. Decision Trees
# 2.  Random Forest
# 3.  Support Vector Machines (SVM)
# 4.  K-Nearest Neighbors (KNN)
# 5.  Naïve Bayes

# %% [markdown]
# #### What are Classification Evaluation Metrics

# %% [markdown]
# When evaluating a classification model, we need metrics that measure how well the model predicts class labels. Below are key metrics used for classification problems.
#
# 1. Accuracy
# 2. Precision (Positive Predictive Value)
# 3. Recall (Sensitivity, True Positive Rate)
# 4. F1 Score (Harmonic Mean of Precision and Recall)
# 5. ROC Curve & AUC (Area Under the Curve)
# 6. Log Loss (Logarithmic Loss, Cross-Entropy Loss)
# 7. Matthews Correlation Coefficient (MCC)

# %% [markdown]
# ####  How does class imbalance affect Logistic Regression

# %% [markdown]
# Class imbalance occurs when one class is significantly more frequent than another in a dataset. This can negatively impact Logistic Regression, leading to poor performance in predicting the minority class.
#
# 1. Biased Model Predictions
# 2. Poor Decision Boundary
# 3. Misleading Evaluation Metrics

# %% [markdown]
# #### What is Hyperparameter Tuning in Logistic Regression

# %% [markdown]
# Hyperparameter tuning is the process of finding the optimal values for hyperparameters to improve model performance. In Logistic Regression, hyperparameters control regularization, optimization, and model complexity.
#
# 1. Regularization Strength (C)
# 2. Type of Regularization (Penalty)
# 3. Solver (Optimization Algorithm)
# 4. Class Weight (Handling Imbalance)

# %% [markdown]
# #### What are different solvers in Logistic Regression? Which one should be used

# %% [markdown]
# Logistic Regression in Scikit-learn provides several solver options for optimization. Each solver has different strengths based on dataset size, regularization, and computational efficiency.
#
# 1. ‘liblinear’ (Best for Small Datasets)
# 2. ‘lbfgs’ (Best for Large Datasets & Multi-Class)
# 3. ‘saga’ (Best for Large Datasets + Supports L1, L2, ElasticNet)
# 4. ‘newton-cg’ (Best for Large & Multi-Class Datasets)
# 5. ‘sag’ (Best for Large, Sparse Datasets)

# %% [markdown]
# ####  How is Logistic Regression extended for multiclass classification

# %% [markdown]
# Logistic Regression is naturally designed for binary classification (two classes: 0 or 1). However, it can be extended to multiclass classification (3 or more classes) using two main approaches:
#
# 1️ One-vs-Rest (OvR) / One-vs-All (OvA)
#
# 2️ Multinomial Logistic Regression (Softmax / One-vs-One)

# %% [markdown]
# #### What are the advantages and disadvantages of Logistic Regression

# %% [markdown]
# Advantages of Logistic Regression
# 1️ Easy to Implement & Interpret
# Straightforward & quick to train compared to complex models.
#
# Output probabilities are easy to understand.
#
# Use Case: Medical diagnosis models where interpretability is key (e.g., predicting heart disease).
#
#
# 2️ Works Well on Linearly Separable Data
#
# If classes can be separated by a straight line/plane, Logistic Regression performs very well.
#
# Use Case: Spam detection when features (e.g., word frequency) separate spam from non-spam.
#
#
# 3️ Computationally Efficient (Fast Training)
# Requires less computation than deep learning or ensemble models.
#
# Trains quickly even on large datasets.
#
# Use Case: Quick, baseline models in real-time applications (e.g., fraud detection).
#
#
# 4️ Outputs Probabilities (Useful for Decision-Making)
# Unlike SVMs or Decision Trees, Logistic Regression provides class probabilities.
#
# Helps in applications where probability matters (e.g., medical risk prediction).
#
#  Use Case: Predicting customer churn, where knowing the churn probability is useful.
#
#
# 5️ Handles Multiple Classes (With Softmax Extension)
# Can be extended to multiclass classification using One-vs-Rest (OvR) or Softmax Regression.
#
# Use Case: Handwritten digit classification (MNIST dataset).
#
#
# 6️ Regularization Helps Prevent Overfitting
# Supports L1 (Lasso) & L2 (Ridge) regularization to handle overfitting.
#
# Use Case: When working with many correlated features, L1/L2 helps prevent overfitting.

# %% [markdown]
# #### What are some use cases of Logistic Regression

# %% [markdown]
# Logistic Regression is widely used for classification problems, especially when interpretability and efficiency are important. Here are some real-world applications:
#
# 1. Medical Diagnosis
# 2. Spam Detection
# 3. redit Scoring & Loan Default Prediction
# 4. Customer Churn Prediction
# 5. Fraud Detection
# 6. Sentiment Analysis
# 7. Employee Attrition Prediction

# %% [markdown]
# #### What is the difference between Softmax Regression and Logistic Regression

# %% [markdown]
# Both Softmax Regression and Logistic Regression are classification algorithms, but they differ in how they handle the number of classes and how they compute probabilities.
#
# 1. Logistic Regression (Binary Classification):-
#
#  Used for: Binary classification (two classes: 0 or 1).
#
#  Activation Function: Sigmoid function
#
#  Output: Single probability (belonging to class 1).
#
#
# 2️ Softmax Regression (Multiclass Classification):-
#
#  Used for: Multiclass classification (3 or more classes: 0, 1, 2, ...).
#
#  Activation Function: Softmax function
#
#  Output: Probability distribution over all classes.
#
#  Decision Rule: The class with the highest probability is chosen.

# %% [markdown]
# #### How do we choose between One-vs-Rest (OvR) and Softmax for multiclass classification

# %% [markdown]
# 1️. One-vs-Rest (OvR) / One-vs-All (OvA)
#  How it works:
#
# Trains multiple binary classifiers (one for each class).
#
# Each classifier predicts whether a sample belongs to that class or not.
#
# The class with the highest probability wins.
#
#
# 2️. Softmax (Multinomial) Regression
# How it works:
#
# Trains one model that considers all classes at the same time.
#
# Uses the Softmax function to compute probabilities for each class.
#
# The class with the highest probability is chosen.

# %% [markdown]
# ####  How do we interpret coefficients in Logistic Regression

# %% [markdown]
# In Logistic Regression, the model predicts the log-odds of an event occurring. The coefficients tell us how each feature influences the log-odds and, consequently, the probability of the outcome.
#
# 1️. Understanding the Logistic Regression Equation
#
# 2. Interpretation of Coefficients
#
# 3️ Using the Odds Ratio for Better Interpretation
#
# 4. Special Cases in Interpretation

# %% [markdown]
# ### Practical

# %% [markdown]
# #### Write a Python program that loads a dataset, splits it into training and testing sets, applies Logistic Regression, and prints the model accuracy

# %%
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = datasets.load_iris()
X, y = iris.data, iris.target  # Features and target labels

# Split data into training (70%) and testing (30%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Train a Logistic Regression model
log_reg = LogisticRegression(max_iter=200, random_state=42)
log_reg.fit(X_train, y_train)

# Make predictions on the test set
y_pred = log_reg.predict(X_test)

# Compute accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print(f"Logistic Regression Model Accuracy: {accuracy:.4f}")
# Out:
# Logistic Regression Model Accuracy: 0.9333

# %% [markdown]
# #### Write a Python program to apply L1 regularization (Lasso) on a dataset using LogisticRegression(penalty='l1') and print the model accuracy

# %%
# Load the Iris dataset
iris = datasets.load_iris()
X, y = iris.data, iris.target  # Features and target labels

# Split data into training (70%) and testing (30%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Train Logistic Regression with L1 Regularization (Lasso)
log_reg_l1 = LogisticRegression(penalty='l1', solver='liblinear', max_iter=200, random_state=42)
log_reg_l1.fit(X_train, y_train)

# Make predictions on the test set
y_pred = log_reg_l1.predict(X_test)

# Compute accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print(f"Logistic Regression (L1 Regularization) Accuracy: {accuracy:.4f}")

# Print the coefficients (Feature Importance)
print("\nFeature Coefficients (L1 Regularization):")
print(log_reg_l1.coef_)
# Out:
# Logistic Regression (L1 Regularization) Accuracy: 0.9333
#
# Feature Coefficients (L1 Regularization):
# [[ 0.          2.32757481 -2.60658691  0.        ]
#  [ 0.64003944 -1.88447241  0.42056902 -1.3386792 ]
#  [-2.57888486 -1.37570267  2.89672845  3.59205875]]

# %% [markdown]
# #### Write a Python program to train Logistic Regression with L2 regularization (Ridge) using LogisticRegression(penalty='l2'). Print model accuracy and coefficients

# %%
# Load the Iris dataset
iris = datasets.load_iris()
X, y = iris.data, iris.target  # Features and target labels

# Split data into training (70%) and testing (30%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Train Logistic Regression with L2 Regularization (Ridge)
log_reg_l2 = LogisticRegression(penalty='l2', solver='lbfgs', max_iter=200, random_state=42)
log_reg_l2.fit(X_train, y_train)

# Make predictions on the test set
y_pred = log_reg_l2.predict(X_test)

# Compute accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print model accuracy
print(f"Logistic Regression (L2 Regularization) Accuracy: {accuracy:.4f}")

# Print feature coefficients
print("\nFeature Coefficients (L2 Regularization):")
print(log_reg_l2.coef_)
# Out:
# Logistic Regression (L2 Regularization) Accuracy: 0.9333
#
# Feature Coefficients (L2 Regularization):
# [[-0.54508415  0.76445111 -2.22894098 -0.97457748]
#  [ 0.42116822 -0.42711734 -0.10046531 -0.83878104]
#  [ 0.12391593 -0.33733377  2.32940629  1.81335852]]

# %% [markdown]
# #### Write a Python program to train Logistic Regression with Elastic Net Regularization (penalty='elasticnet')

# %%
# Load the Iris dataset
iris = datasets.load_iris()
X, y = iris.data, iris.target  # Features and target labels

# Split data into training (70%) and testing (30%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Train Logistic Regression with Elastic Net Regularization
log_reg_elastic = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=0.5, max_iter=200, random_state=42)
log_reg_elastic.fit(X_train, y_train)

# Make predictions on the test set
y_pred = log_reg_elastic.predict(X_test)

# Compute accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print model accuracy
print(f"Logistic Regression (Elastic Net Regularization) Accuracy: {accuracy:.4f}")

# Print feature coefficients
print("\nFeature Coefficients (Elastic Net Regularization):")
print(log_reg_elastic.coef_)
# Out:
# Logistic Regression (Elastic Net Regularization) Accuracy: 1.0000
#
# Feature Coefficients (Elastic Net Regularization):
# [[ 0.3921746   1.72215029 -2.34310712 -0.75045407]
#  [ 0.06215009 -0.02438313  0.         -0.58712092]
#  [-1.24738433 -0.90379447  2.24485472  2.1311626 ]]
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %% [markdown]
# #### Write a Python program to train a Logistic Regression model for multiclass classification using multi_class='ovr'

# %%
from sklearn.metrics import accuracy_score, classification_report

# Load the Iris dataset (Multiclass Classification Problem)
iris = datasets.load_iris()
X, y = iris.data, iris.target  # Features and target labels

# Split data into training (70%) and testing (30%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Train Logistic Regression using One-vs-Rest (OvR) strategy
log_reg_ovr = LogisticRegression(multi_class='ovr', solver='lbfgs', max_iter=200, random_state=42)
log_reg_ovr.fit(X_train, y_train)

# Make predictions on the test set
y_pred = log_reg_ovr.predict(X_test)

# Compute accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print model accuracy
print(f"Logistic Regression (OvR) Accuracy: {accuracy:.4f}")

# Print classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
# Logistic Regression (OvR) Accuracy: 0.8889
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.86      0.80      0.83        15
#    virginica       0.81      0.87      0.84        15
#
#     accuracy                           0.89        45
#    macro avg       0.89      0.89      0.89        45
# weighted avg       0.89      0.89      0.89        45
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(

# %% [markdown]
# #### Write a Python program to apply GridSearchCV to tune the hyperparameters (C and penalty) of Logistic Regression. Print the best parameters and accuracy

# %%
from sklearn.model_selection import train_test_split, GridSearchCV


# Load the Iris dataset
iris = datasets.load_iris()
X, y = iris.data, iris.target  # Features and target labels

# Split data into training (70%) and testing (30%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Define the Logistic Regression model
log_reg = LogisticRegression(solver='saga', max_iter=500, random_state=42)

# Define hyperparameter grid for GridSearchCV
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],  # Regularization strength
    'penalty': ['l1', 'l2']  # L1 (Lasso) or L2 (Ridge) regularization
}

# Perform GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(log_reg, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)

# Get the best parameters and best model
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

# Make predictions with the best model
y_pred = best_model.predict(X_test)

# Compute accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the best hyperparameters and accuracy
print(f"Best Hyperparameters: {best_params}")
print(f"Accuracy of Optimized Logistic Regression: {accuracy:.4f}\n")

# Print Detailed Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
# Best Hyperparameters: {'C': 10, 'penalty': 'l1'}
# Accuracy of Optimized Logistic Regression: 0.9778
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.94      1.00      0.97        15
#    virginica       1.00      0.93      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %% [markdown]
# #### Write a Python program to evaluate Logistic Regression using Stratified K-Fold Cross-Validation. Print theaverage accuracy

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score


# Load the Iris dataset
iris = datasets.load_iris()
X, y = iris.data, iris.target  # Features and target labels

# Define Logistic Regression model
log_reg = LogisticRegression(solver='lbfgs', max_iter=200, random_state=42)

# Define Stratified K-Fold Cross-Validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Perform Cross-Validation and compute accuracy scores
accuracy_scores = cross_val_score(log_reg, X, y, cv=skf, scoring='accuracy')

# Compute and print the average accuracy
average_accuracy = np.mean(accuracy_scores)
print(f"Average Accuracy from Stratified K-Fold Cross-Validation: {average_accuracy:.4f}")
# Out:
# Average Accuracy from Stratified K-Fold Cross-Validation: 0.9667

# %% [markdown]
# #### Write a Python program to load a dataset from a CSV file, apply Logistic Regression, and evaluate its accuracy

# %%
# # 📌 Load dataset from CSV file
# file_path = r"../Dataset/HRDataset_v14.csv"  # 🔄 Update with your actual file path
# df = pd.read_csv(file_path)

# # 🔎 Step 2: Explore the dataset
# print("Dataset Preview:\n", df.head())
# print("\nDataset Info:\n", df.info())

# # 🛠️ Step 3: Handle Missing Values (Drop or Fill)
# df.dropna(inplace=True)  # Remove rows with missing values

# # 🏷️ Step 4: Encode Categorical Variables
# df = pd.get_dummies(df, drop_first=True)  # One-hot encoding

# # 🎯 Step 5: Define Features & Target
# y = df.iloc[:, -1]  # Assuming last column is the target variable
# X = df.iloc[:, :-1]  # All columns except the last one

# # ✅ Ensure Target Variable is Categorical
# if y.dtype in ['int64', 'float64']:
#     y = y.astype(str)  # Convert to categorical if needed

# # 🚀 Step 6: Train-Test Split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# # 🔄 Step 7: Scale the Features (Optional but Recommended)
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# # 🏆 Step 8: Train Logistic Regression Model
# log_reg = LogisticRegression(max_iter=200, random_state=42)
# log_reg.fit(X_train, y_train)

# # 📊 Step 9: Make Predictions
# y_pred = log_reg.predict(X_test)

# # ✅ Step 10: Evaluate Model Performance
# accuracy = accuracy_score(y_test, y_pred)
# print(f"\n🔹 Logistic Regression Model Accuracy: {accuracy:.4f}")

# #Step 11: Display Classification Report
# print("\n📌 Classification Report:")
# print(classification_report(y_test, y_pred))

# %% [markdown]
# #### Write a Python program to apply RandomizedSearchCV for tuning hyperparameters (C, penalty, solver) in Logistic Regression. Print the best parameters and accuracy

# %%
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.datasets import load_breast_cancer

# 🎯 Load Dataset (Breast Cancer Dataset for Classification)
data = load_breast_cancer()
X, y = data.data, data.target

# ✅ Apply Stratified Splitting
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# 🎯 Define Logistic Regression Model
log_reg = LogisticRegression(max_iter=500, random_state=42)

# 🔍 Define Hyperparameter Grid for RandomizedSearchCV
param_dist = {
    'C': np.logspace(-4, 4, 20),  # Regularization strength
    'penalty': ['l1', 'l2'],      # L1 = Lasso, L2 = Ridge
    'solver': ['liblinear', 'saga']  # Compatible solvers
}

# 🚀 Perform RandomizedSearchCV (Randomized Hyperparameter Tuning)
random_search = RandomizedSearchCV(
    log_reg, param_distributions=param_dist, n_iter=20, 
    scoring='accuracy', cv=5, random_state=42, n_jobs=-1
)

# 🏋️ Train Model with RandomizedSearchCV
random_search.fit(X_train, y_train)

# ✅ Get Best Parameters
best_params = random_search.best_params_
print(f"\n🔹 Best Hyperparameters: {best_params}")

# 📊 Evaluate Best Model
best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test)

# ✅ Compute Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"\n🚀 Logistic Regression Model Accuracy (After Tuning): {accuracy:.4f}")

# 📄 Classification Report
print("\n📌 Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 🔹 Best Hyperparameters: {'solver': 'liblinear', 'penalty': 'l2', 'C': 1438.44988828766}
#
# 🚀 Logistic Regression Model Accuracy (After Tuning): 0.9474
#
# 📌 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93        64
#            1       0.94      0.98      0.96       107
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.94      0.94       171
# weighted avg       0.95      0.95      0.95       171

# %% [markdown]
# #### Write a Python program to implement One-vs-One (OvO) Multiclass Logistic Regression and print accuracy

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsOneClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.datasets import load_wine

# 🎯 Load a Multiclass Dataset (Wine Dataset)
data = load_wine()
X, y = data.data, data.target  # Features and target

# ✅ Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# 🎯 Define One-vs-One Logistic Regression Model
ovo_model = OneVsOneClassifier(LogisticRegression(max_iter=500, random_state=42))

# 🏋️ Train the Model
ovo_model.fit(X_train, y_train)

# 🔍 Predict on Test Data
y_pred = ovo_model.predict(X_test)

# ✅ Compute Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"\n🚀 One-vs-One Logistic Regression Accuracy: {accuracy:.4f}")

# 📄 Classification Report
print("\n📌 Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# #### Write a Python program to train a Logistic Regression model and visualize the confusion matrix for binary classification

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.datasets import load_breast_cancer

# 🎯 Load Binary Classification Dataset (Breast Cancer)
data = load_breast_cancer()
X, y = data.data, data.target  # Features and target (binary: 0 = Malignant, 1 = Benign)

# ✅ Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# 🎯 Train Logistic Regression Model
log_reg = LogisticRegression(max_iter=500, random_state=42)
log_reg.fit(X_train, y_train)

# 🔍 Predict on Test Data
y_pred = log_reg.predict(X_test)

# ✅ Compute Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"\n🚀 Logistic Regression Accuracy: {accuracy:.4f}")

# 📄 Classification Report
print("\n📌 Classification Report:")
print(classification_report(y_test, y_pred))

# 🔥 Compute Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# 🎨 Visualize Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Malignant', 'Benign'], yticklabels=['Malignant', 'Benign'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 🚀 Logistic Regression Accuracy: 0.9415
#
# 📌 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92        64
#            1       0.93      0.98      0.95       107
#
#     accuracy                           0.94       171
#    macro avg       0.95      0.93      0.94       171
# weighted avg       0.94      0.94      0.94       171

# %% [markdown]
# #### Write a Python program to train a Logistic Regression model and evaluate its performance using Precision, Recall, and F1-Score

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
from sklearn.datasets import load_breast_cancer

# 🎯 Load Binary Classification Dataset (Breast Cancer)
data = load_breast_cancer()
X, y = data.data, data.target  # Features and target (binary: 0 = Malignant, 1 = Benign)

# ✅ Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# 🎯 Train Logistic Regression Model
log_reg = LogisticRegression(max_iter=500, random_state=42)
log_reg.fit(X_train, y_train)

# 🔍 Predict on Test Data
y_pred = log_reg.predict(X_test)

# ✅ Compute Evaluation Metrics
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# 🔹 Print Precision, Recall, and F1-Score
print(f"\n🔹 Precision: {precision:.4f}")
print(f"🔹 Recall: {recall:.4f}")
print(f"🔹 F1-Score: {f1:.4f}")

# 📄 Detailed Classification Report
print("\n📌 Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 🔹 Precision: 0.9292
# 🔹 Recall: 0.9813
# 🔹 F1-Score: 0.9545
#
# 📌 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92        64
#            1       0.93      0.98      0.95       107
#
#     accuracy                           0.94       171
#    macro avg       0.95      0.93      0.94       171
# weighted avg       0.94      0.94      0.94       171
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# #### Write a Python program to train a Logistic Regression model on imbalanced data and apply class weights to improve model performance

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
from sklearn.datasets import make_classification
from collections import Counter

# 🎯 Generate an Imbalanced Dataset
X, y = make_classification(n_samples=5000, n_features=20, n_classes=2, 
                           weights=[0.90, 0.10], random_state=42)

# ✅ Check Class Distribution
print(f"\n🔍 Class Distribution: {Counter(y)}")

# ✅ Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# 🎯 Train Logistic Regression Model (WITHOUT Class Weights)
log_reg = LogisticRegression(max_iter=500, random_state=42)
log_reg.fit(X_train, y_train)
y_pred_no_weight = log_reg.predict(X_test)

# ✅ Train Logistic Regression Model (WITH Class Weights)
log_reg_balanced = LogisticRegression(max_iter=500, random_state=42, class_weight='balanced')
log_reg_balanced.fit(X_train, y_train)
y_pred_weighted = log_reg_balanced.predict(X_test)

# ✅ Evaluate Performance
def evaluate_model(y_true, y_pred, title):
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    print(f"\n📌 {title}")
    print(f"🔹 Precision: {precision:.4f}")
    print(f"🔹 Recall: {recall:.4f}")
    print(f"🔹 F1-Score: {f1:.4f}")
    print(classification_report(y_true, y_pred))

# 🔥 Compare Models
evaluate_model(y_test, y_pred_no_weight, "Model WITHOUT Class Weights")
evaluate_model(y_test, y_pred_weighted, "Model WITH Class Weights")

# 🎨 Confusion Matrix Visualization
def plot_confusion_matrix(y_true, y_pred, title):
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(5, 4))
    sns
# Out:
# 🔍 Class Distribution: Counter({0: 4477, 1: 523})
#
# 📌 Model WITHOUT Class Weights
# 🔹 Precision: 0.7767
# 🔹 Recall: 0.5096
# 🔹 F1-Score: 0.6154
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      1343
#            1       0.78      0.51      0.62       157
#
#     accuracy                           0.93      1500
#    macro avg       0.86      0.75      0.79      1500
# weighted avg       0.93      0.93      0.93      1500
#
#
# 📌 Model WITH Class Weights
# 🔹 Precision: 0.4050
# 🔹 Recall: 0.8280
# 🔹 F1-Score: 0.5439
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.91      1343
#            1       0.40      0.83      0.54       157
#
#     accuracy                           0.85      1500
#    macro avg       0.69      0.84      0.73      1500
# weighted avg       0.92      0.85      0.87      1500

# %% [markdown]
# #### Write a Python program to train Logistic Regression on the Titanic dataset, handle missing values, and evaluate performance

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# 🎯 Load Titanic Dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# ✅ Select Relevant Features
features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
target = 'Survived'
df = df[features + [target]]

# ✅ Handle Missing Values
df['Age'].fillna(df['Age'].median(), inplace=True)  # Fill missing Age with median
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)  # Fill missing Embarked with mode

# ✅ Encode Categorical Features (Sex, Embarked)
df = pd.get_dummies(df, columns=['Sex', 'Embarked'], drop_first=True)

# ✅ Split Data into Features and Target
X = df.drop(columns=[target])
y = df[target]

# ✅ Split into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ✅ Scale Numerical Features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 🎯 Train Logistic Regression Model
log_reg = LogisticRegression(max_iter=500, random_state=42)
log_reg.fit(X_train, y_train)

# 🔍 Predict on Test Data
y_pred = log_reg.predict(X_test)

# ✅ Evaluate Model Performance
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"\n🚀 Logistic Regression Model Performance:")
print(f"🔹 Accuracy: {accuracy:.4f}")
print(f"🔹 Precision: {precision:.4f}")
print(f"🔹 Recall: {recall:.4f}")
print(f"🔹 F1-Score: {f1:.4f}")

# 📄 Detailed Classification Report
print("\n📌 Classification Report:")
print(classification_report(y_test, y_pred))

# 🎨 Confusion Matrix Visualization
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Survived', 'Survived'], yticklabels=['Not Survived', 'Survived'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\AppData\Local\Temp\ipykernel_10116\1877610573.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)  # Fill missing Age with median
# C:\Users\ITProFound_Hyd_024\AppData\Local\Temp\ipykernel_10116\1877610573.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# #### Write a Python program to apply feature scaling (Standardization) before training a Logistic Regression model. Evaluate its accuracy and compare results with and without scaling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.datasets import load_breast_cancer

# 🎯 Load Dataset (Binary Classification - Breast Cancer)
data = load_breast_cancer()
X, y = data.data, data.target  # Features and Target

# ✅ Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

### 🚀 1️⃣ Logistic Regression WITHOUT Feature Scaling
log_reg_no_scaling = LogisticRegression(max_iter=500, random_state=42)
log_reg_no_scaling.fit(X_train, y_train)
y_pred_no_scaling = log_reg_no_scaling.predict(X_test)

# ✅ Compute Accuracy Without Scaling
accuracy_no_scaling = accuracy_score(y_test, y_pred_no_scaling)

### 🚀 2️⃣ Logistic Regression WITH Standardization
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

log_reg_scaled = LogisticRegression(max_iter=500, random_state=42)
log_reg_scaled.fit(X_train_scaled, y_train)
y_pred_scaled = log_reg_scaled.predict(X_test_scaled)

# ✅ Compute Accuracy With Scaling
accuracy_scaled = accuracy_score(y_test, y_pred_scaled)

# 🔹 Print Results
print("\n🚀 Logistic Regression Model Performance Comparison:")
print(f"🔹 Accuracy WITHOUT Scaling: {accuracy_no_scaling:.4f}")
print(f"🔹 Accuracy WITH Standardization: {accuracy_scaled:.4f}")

# 📄 Detailed Classification Report (With Scaling)
print("\n📌 Classification Report (With Scaling):")
print(classification_report(y_test, y_pred_scaled))

# 🎨 Confusion Matrix Visualization (With Scaling)
cm = confusion_matrix(y_test, y_pred_scaled)

plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Malignant', 'Benign'], yticklabels=['Malignant', 'Benign'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix (With Scaling)")
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 🚀 Logistic Regression Model Performance Comparison:
# 🔹 Accuracy WITHOUT Scaling: 0.9415
# 🔹 Accuracy WITH Standardization: 0.9883
#
# 📌 Classification Report (With Scaling):
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        64
#            1       0.99      0.99      0.99       107
#
#     accuracy                           0.99       171
# ...

# %% [markdown]
# #### Write a Python program to train Logistic Regression and evaluate its performance using ROC-AUC score

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.datasets import load_breast_cancer

# 🎯 Load Dataset (Binary Classification - Breast Cancer)
data = load_breast_cancer()
X, y = data.data, data.target  # Features and Target

# ✅ Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ✅ Apply Feature Scaling (Standardization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 🎯 Train Logistic Regression Model
log_reg = LogisticRegression(max_iter=500, random_state=42)
log_reg.fit(X_train_scaled, y_train)

# 🔍 Predict Probabilities
y_probs = log_reg.predict_proba(X_test_scaled)[:, 1]  # Get probability of class 1

# ✅ Compute ROC-AUC Score
roc_auc = roc_auc_score(y_test, y_probs)
print(f"\n🚀 Logistic Regression Model ROC-AUC Score: {roc_auc:.4f}")

# 🎨 Plot ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_probs)  # Compute ROC curve
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, color='blue', label=f'Logistic Regression (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # Diagonal Line (Random Classifier)
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.title("ROC Curve for Logistic Regression")
plt.legend()
plt.show()
# Out:
# 🚀 Logistic Regression Model ROC-AUC Score: 0.9981

# %% [markdown]
# #### Write a Python program to train Logistic Regression using a custom learning rate (C=0.5) and evaluate accuracy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.datasets import load_breast_cancer

# 🎯 Load Dataset (Binary Classification - Breast Cancer)
data = load_breast_cancer()
X, y = data.data, data.target  # Features and Target

# ✅ Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ✅ Apply Feature Scaling (Standardization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 🎯 Train Logistic Regression Model with Custom Learning Rate (C=0.5)
log_reg = LogisticRegression(C=0.5, max_iter=500, random_state=42)
log_reg.fit(X_train_scaled, y_train)

# 🔍 Predict on Test Data
y_pred = log_reg.predict(X_test_scaled)

# ✅ Compute Accuracy
accuracy = accuracy_score(y_test, y_pred)

print(f"\n🚀 Logistic Regression Model Accuracy (C=0.5): {accuracy:.4f}")

# 📄 Detailed Classification Report
print("\n📌 Classification Report:")
print(classification_report(y_test, y_pred))

# 🎨 Confusion Matrix Visualization
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Malignant', 'Benign'], yticklabels=['Malignant', 'Benign'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix (C=0.5)")
plt.show()
# Out:
# 🚀 Logistic Regression Model Accuracy (C=0.5): 0.9825
#
# 📌 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98        64
#            1       0.98      0.99      0.99       107
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %% [markdown]
# #### Write a Python program to train Logistic Regression and identify important features based on model coefficients

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_breast_cancer

# 🎯 Load Dataset (Breast Cancer - Binary Classification)
data = load_breast_cancer()
X, y = data.data, data.target  # Features and Target
feature_names = data.feature_names  # Feature names

# ✅ Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ✅ Apply Feature Scaling (Standardization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 🎯 Train Logistic Regression Model
log_reg = LogisticRegression(max_iter=500, random_state=42)
log_reg.fit(X_train_scaled, y_train)

# 🔍 Extract Feature Importance (Model Coefficients)
feature_importance = log_reg.coef_[0]  # Get coefficients
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Coefficient': feature_importance})

# ✅ Sort Features by Importance (Descending)
feature_importance_df = feature_importance_df.reindex(feature_importance_df.Coefficient.abs().sort_values(ascending=False).index)

# 📊 Visualize Feature Importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Coefficient', y='Feature', data=feature_importance_df, palette='coolwarm')
plt.xlabel("Coefficient Value")
plt.ylabel("Feature")
plt.title("Top Important Features in Logistic Regression")
plt.axvline(x=0, color='black', linestyle='--')
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\AppData\Local\Temp\ipykernel_10116\4075004100.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Coefficient', y='Feature', data=feature_importance_df, palette='coolwarm')

# %% [markdown]
# #### Write a Python program to train Logistic Regression and evaluate its performance using Cohen’s Kappa Score

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix
from sklearn.datasets import load_breast_cancer

# 🎯 Load Dataset (Breast Cancer - Binary Classification)
data = load_breast_cancer()
X, y = data.data, data.target  # Features and Target

# ✅ Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ✅ Apply Feature Scaling (Standardization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 🎯 Train Logistic Regression Model
log_reg = LogisticRegression(max_iter=500, random_state=42)
log_reg.fit(X_train_scaled, y_train)

# 🔍 Predict on Test Data
y_pred = log_reg.predict(X_test_scaled)

# ✅ Compute Accuracy
accuracy = accuracy_score(y_test, y_pred)

# ✅ Compute Cohen's Kappa Score
kappa_score = cohen_kappa_score(y_test, y_pred)

print(f"\n🚀 Logistic Regression Model Accuracy: {accuracy:.4f}")
print(f"📌 Cohen's Kappa Score: {kappa_score:.4f}")

# 🎨 Confusion Matrix Visualization
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Malignant', 'Benign'], yticklabels=['Malignant', 'Benign'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 🚀 Logistic Regression Model Accuracy: 0.9883
# 📌 Cohen's Kappa Score: 0.9750

# %% [markdown]
# #### Write a Python program to train Logistic Regression and visualize the Precision-Recall Curve for binary classificatio:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_curve, auc
from sklearn.datasets import load_breast_cancer

# 🎯 Load Dataset (Breast Cancer - Binary Classification)
data = load_breast_cancer()
X, y = data.data, data.target  # Features and Target

# ✅ Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ✅ Apply Feature Scaling (Standardization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 🎯 Train Logistic Regression Model
log_reg = LogisticRegression(max_iter=500, random_state=42)
log_reg.fit(X_train_scaled, y_train)

# 🔍 Predict Probabilities
y_probs = log_reg.predict_proba(X_test_scaled)[:, 1]  # Probability of positive class

# ✅ Compute Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test, y_probs)
pr_auc = auc(recall, precision)  # Compute AUC for PR curve

# 🎨 Plot Precision-Recall Curve
plt.figure(figsize=(6, 5))
plt.plot(recall, precision, color='blue', label=f'Logistic Regression (AUC = {pr_auc:.4f})')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve for Logistic Regression")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### Write a Python program to train Logistic Regression with different solvers (liblinear, saga, lbfgs) and compare their accuracy

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_breast_cancer

# 🎯 Load Dataset (Breast Cancer - Binary Classification)
data = load_breast_cancer()
X, y = data.data, data.target  # Features and Target

# ✅ Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ✅ Apply Feature Scaling (Standardization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 🎯 Define Solvers to Compare
solvers = ['liblinear', 'saga', 'lbfgs']
results = {}

# 🔍 Train Logistic Regression with Different Solvers
for solver in solvers:
    log_reg = LogisticRegression(solver=solver, max_iter=500, random_state=42)
    log_reg.fit(X_train_scaled, y_train)
    y_pred = log_reg.predict(X_test_scaled)
    
    # ✅ Compute Accuracy
    accuracy = accuracy_score(y_test, y_pred)
    results[solver] = accuracy
    print(f"🚀 Solver: {solver} | Accuracy: {accuracy:.4f}")

# 📊 Convert Results to DataFrame
results_df = pd.DataFrame(list(results.items()), columns=['Solver', 'Accuracy'])

# 🎨 Plot Comparison
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 4))
sns.barplot(x='Solver', y='Accuracy', data=results_df, palette='viridis')
plt.xlabel("Solver")
plt.ylabel("Accuracy")
plt.title("Comparison of Logistic Regression Solvers")
plt.ylim(0.95, 1)  # Adjust y-axis for better visualization
plt.show()
# Out:
# 🚀 Solver: liblinear | Accuracy: 0.9883
# 🚀 Solver: saga | Accuracy: 0.9883
# 🚀 Solver: lbfgs | Accuracy: 0.9883
# C:\Users\ITProFound_Hyd_024\AppData\Local\Temp\ipykernel_10116\3995322670.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Solver', y='Accuracy', data=results_df, palette='viridis')

# %% [markdown]
# #### Write a Python program to train Logistic Regression and evaluate its performance using Matthews Correlation Coefficient (MCC)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, matthews_corrcoef, confusion_matrix
from sklearn.datasets import load_breast_cancer

# 🎯 Load Dataset (Breast Cancer - Binary Classification)
data = load_breast_cancer()
X, y = data.data, data.target  # Features and Target

# ✅ Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ✅ Apply Feature Scaling (Standardization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 🎯 Train Logistic Regression Model
log_reg = LogisticRegression(max_iter=500, random_state=42)
log_reg.fit(X_train_scaled, y_train)

# 🔍 Predict on Test Data
y_pred = log_reg.predict(X_test_scaled)

# ✅ Compute Accuracy
accuracy = accuracy_score(y_test, y_pred)

# ✅ Compute Matthews Correlation Coefficient (MCC)
mcc_score = matthews_corrcoef(y_test, y_pred)

print(f"\n🚀 Logistic Regression Model Accuracy: {accuracy:.4f}")
print(f"📌 Matthews Correlation Coefficient (MCC): {mcc_score:.4f}")

# 🎨 Confusion Matrix Visualization
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Malignant', 'Benign'], yticklabels=['Malignant', 'Benign'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 🚀 Logistic Regression Model Accuracy: 0.9883
# 📌 Matthews Correlation Coefficient (MCC): 0.9750

# %% [markdown]
# #### Write a Python program to train Logistic Regression on both raw and standardized data. Compare their accuracy to see the impact of feature scaling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_breast_cancer

# 🎯 Load Dataset (Breast Cancer - Binary Classification)
data = load_breast_cancer()
X, y = data.data, data.target  # Features and Target

# ✅ Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# 🎯 Train Logistic Regression on RAW Data (No Scaling)
log_reg_raw = LogisticRegression(max_iter=500, random_state=42)
log_reg_raw.fit(X_train, y_train)
y_pred_raw = log_reg_raw.predict(X_test)
accuracy_raw = accuracy_score(y_test, y_pred_raw)

# ✅ Apply Feature Scaling (Standardization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 🎯 Train Logistic Regression on STANDARDIZED Data
log_reg_scaled = LogisticRegression(max_iter=500, random_state=42)
log_reg_scaled.fit(X_train_scaled, y_train)
y_pred_scaled = log_reg_scaled.predict(X_test_scaled)
accuracy_scaled = accuracy_score(y_test, y_pred_scaled)

# 📌 Compare Accuracy
print(f"🚀 Accuracy on RAW Data: {accuracy_raw:.4f}")
print(f"📌 Accuracy on STANDARDIZED Data: {accuracy_scaled:.4f}")

# 📊 Visualize Comparison
accuracy_data = pd.DataFrame({
    "Data Type": ["Raw Data", "Standardized Data"],
    "Accuracy": [accuracy_raw, accuracy_scaled]
})

plt.figure(figsize=(6, 4))
sns.barplot(x="Data Type", y="Accuracy", data=accuracy_data, palette="coolwarm")
plt.xlabel("Data Type")
plt.ylabel("Accuracy")
plt.title("Impact of Feature Scaling on Logistic Regression")
plt.ylim(0.90, 1)  # Adjust y-axis for better visualization
plt.show()
# Out:
# C:\Users\ITProFound_Hyd_024\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\ITProFound_Hyd_024\AppData\Local\Temp\ipykernel_10116\4010491309.py:48: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Data Type", y="Accuracy", data=accuracy_data, palette="coolwarm")
# 🚀 Accuracy on RAW Data: 0.9415
# 📌 Accuracy on STANDARDIZED Data: 0.9883

# %% [markdown]
# #### Write a Python program to train Logistic Regression and find the optimal C (regularization strength) using cross-validation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_breast_cancer

# 🎯 Load Dataset (Breast Cancer - Binary Classification)
data = load_breast_cancer()
X, y = data.data, data.target  # Features and Target

# ✅ Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ✅ Apply Feature Scaling (Standardization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 🎯 Define Logistic Regression Model
log_reg = LogisticRegression(max_iter=500, random_state=42)

# 🔍 Define Hyperparameter Grid for `C` (Regularization Strength)
param_grid = {'C': np.logspace(-4, 4, 20)}  # Values from 0.0001 to 10,000

# 🚀 Perform Grid Search with 5-Fold Cross-Validation
grid_search = GridSearchCV(log_reg, param_grid, scoring='accuracy', cv=5, n_jobs=-1)
grid_search.fit(X_train_scaled, y_train)

# ✅ Get Best Parameters
best_C = grid_search.best_params_['C']
print(f"\n🔹 Best Regularization Strength (C): {best_C}")

# 🎯 Train Logistic Regression with Best `C`
best_log_reg = LogisticRegression(C=best_C, max_iter=500, random_state=42)
best_log_reg.fit(X_train_scaled, y_train)

# 🔍 Predict on Test Data
y_pred = best_log_reg.predict(X_test_scaled)

# ✅ Compute Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"\n🚀 Logistic Regression Model Accuracy (Optimal C={best_C}): {accuracy:.4f}")

# 📊 Visualize Grid Search Results
results_df = pd.DataFrame(grid_search.cv_results_)
plt.figure(figsize=(8, 5))
plt.semilogx(results_df['param_C'], results_df['mean_test_score'], marker='o', linestyle='-', color='b')
plt.xlabel("C (Regularization Strength)")
plt.ylabel("Accuracy")
plt.title("Grid Search Results: C vs. Accuracy")
plt.show()
# Out:
# 🔹 Best Regularization Strength (C): 0.615848211066026
#
# 🚀 Logistic Regression Model Accuracy (Optimal C=0.615848211066026): 0.9883

# %% [markdown]
# #### Write a Python program to train Logistic Regression, save the trained model using joblib, and load it again to make predictions

# %%
import numpy as np
import joblib  # For saving and loading models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_breast_cancer

# 🎯 Load Dataset (Breast Cancer - Binary Classification)
data = load_breast_cancer()
X, y = data.data, data.target  # Features and Target

# ✅ Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ✅ Apply Feature Scaling (Standardization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 🎯 Train Logistic Regression Model
log_reg = LogisticRegression(max_iter=500, random_state=42)
log_reg.fit(X_train_scaled, y_train)

# 🔹 Save Model Using `joblib`
joblib.dump(log_reg, "logistic_regression_model.pkl")
print("✅ Model saved successfully!")

# 🔄 Load the Saved Model
loaded_model = joblib.load("logistic_regression_model.pkl")
print("✅ Model loaded successfully!")

# 🔍 Make Predictions Using Loaded Model
y_pred = loaded_model.predict(X_test_scaled)

# ✅ Compute Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"\n🚀 Logistic Regression Model Accuracy (Loaded Model): {accuracy:.4f}")
# Out:
# ✅ Model saved successfully!
# ✅ Model loaded successfully!
#
# 🚀 Logistic Regression Model Accuracy (Loaded Model): 0.9883
